# %%
import pandas as pd

# %%
pokemons=pd.read_csv('Pokemon.csv', index_col='#')
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %%
pokemons.describe().round()
# Out:
#        Total     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# count  800.0  800.0   800.0    800.0    800.0    800.0  800.0       800.0
# mean   435.0   69.0    79.0     74.0     73.0     72.0   68.0         3.0
# std    120.0   26.0    32.0     31.0     33.0     28.0   29.0         2.0
# min    180.0    1.0     5.0      5.0     10.0     20.0    5.0         1.0
# 25%    330.0   50.0    55.0     50.0     50.0     50.0   45.0         2.0
# 50%    450.0   65.0    75.0     70.0     65.0     70.0   65.0         3.0
# 75%    515.0   80.0   100.0     90.0     95.0     90.0   90.0         5.0
# max    780.0  255.0   190.0    230.0    194.0    230.0  180.0         6.0

# %%
pokemons.describe(exclude=['int','float'])
# Out:
#              Name Type 1  Type 2 Legendary
# count         800    800     414       800
# unique        800     18      18         2
# top     Bulbasaur  Water  Flying     False
# freq            1    112      97       735

# %%
pokemons.loc[pokemons['Name'] == 'Pikachu']
# Out:
#        Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 25  Pikachu  Electric    NaN    320  35      55       40       50       50
#
#     Speed  Generation  Legendary
# #
# 25     90           1      False

# %%
speed = pokemons['Speed'] > 100
legandary = pokemons['Legendary'] == True 
pokemons[legandary & speed]
# Out:
#                          Name    Type 1    Type 2  Total   HP  Attack  \
# #
# 150                    Mewtwo   Psychic       NaN    680  106     110
# 150       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 243                    Raikou  Electric       NaN    580   90      85
# 249                     Lugia   Psychic    Flying    680  106      90
# 380                    Latias    Dragon   Psychic    600   80      80
# 380         LatiasMega Latias    Dragon   Psychic    700   80     100
# 381                    Latios    Dragon   Psychic    600   80      90
# 381         LatiosMega Latios    Dragon   Psychic    700   80     130
# 384     RayquazaMega Rayquaza    Dragon    Flying    780  105     180
# 386        DeoxysNormal Forme   Psychic       NaN    600   50     150
# 386        DeoxysAttack Forme   Psychic       NaN    600   50     180
# ...

# %%
pokemons['Name_Length'] = pokemons['Name'].apply(len)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Name_Length
# #
# ...

# %%
del pokemons['Name_Length']

# %%
def strength(attack: int) -> str:
    if attack > 150:
        return 'Strong'
    elif attack > 100:
        return 'Average'
    else:
        return 'Weak'

# %%
pokemons['Strength'] = pokemons['Attack'].apply(strength)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Strength
# #
# ...

# %%
pokemons.value_counts('Strength')
# Out:
# Strength
# Weak       630
# Average    152
# Strong      18
# Name: count, dtype: int64

# %%
del pokemons['Strength']

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %%
def score(row):
    attack: int = row['Attack']
    speed: int = row['Speed']
    defense: int = row['Defense']
    return sum([attack, speed, defense])

# %%
pokemons['Score'] = pokemons.apply(score, axis=1)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Score
# #
# ...

# %%
short_name =pokemons['Name'].apply(lambda x:x[:5])
pokemons.insert(0, 'Short_name', short_name)
pokemons
# Out:
#     Short_name                   Name   Type 1  Type 2  Total  HP  Attack  \
# #
# 1        Bulba              Bulbasaur    Grass  Poison    318  45      49
# 2        Ivysa                Ivysaur    Grass  Poison    405  60      62
# 3        Venus               Venusaur    Grass  Poison    525  80      82
# 3        Venus  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        Charm             Charmander     Fire     NaN    309  39      52
# ..         ...                    ...      ...     ...    ...  ..     ...
# 719      Dianc                Diancie     Rock   Fairy    600  50     100
# 719      Dianc    DiancieMega Diancie     Rock   Fairy    700  50     160
# 720      Hoopa    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 720      Hoopa     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 721      Volca              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Score
# #
# ...

# %%
#pokemons.drop('short', axis=1, inplace=True)
del pokemons['Short_name']

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Short_name  800 non-null    object
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
#  13  Score       800 non-null    int64
# dtypes: bool(1), int64(9), object(4)
# memory usage: 88.3+ KB

# %%
pokemons.value_counts('Generation')
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
pokemons['Legendary'] = pokemons['Legendary'].map({True:'Yes', False:'No'})
pokemons
# Out:
#     Short_name                   Name   Type 1  Type 2  Total  HP  Attack  \
# #
# 1        Bulba              Bulbasaur    Grass  Poison    318  45      49
# 2        Ivysa                Ivysaur    Grass  Poison    405  60      62
# 3        Venus               Venusaur    Grass  Poison    525  80      82
# 3        Venus  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        Charm             Charmander     Fire     NaN    309  39      52
# ..         ...                    ...      ...     ...    ...  ..     ...
# 719      Dianc                Diancie     Rock   Fairy    600  50     100
# 719      Dianc    DiancieMega Diancie     Rock   Fairy    700  50     160
# 720      Hoopa    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 720      Hoopa     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 721      Volca              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary  Score
# #
# ...

# %%
pokemons['Generation'] = pokemons['Generation'].map({1: 'First', 2: 'Second'})
pokemons
# Out:
#     Short_name                   Name   Type 1  Type 2  Total  HP  Attack  \
# #
# 1        Bulba              Bulbasaur    Grass  Poison    318  45      49
# 2        Ivysa                Ivysaur    Grass  Poison    405  60      62
# 3        Venus               Venusaur    Grass  Poison    525  80      82
# 3        Venus  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        Charm             Charmander     Fire     NaN    309  39      52
# ..         ...                    ...      ...     ...    ...  ..     ...
# 719      Dianc                Diancie     Rock   Fairy    600  50     100
# 719      Dianc    DiancieMega Diancie     Rock   Fairy    700  50     160
# 720      Hoopa    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 720      Hoopa     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 721      Volca              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary  Score
# #
# ...

# %%
pokemons['Generation'].value_counts()
# Out:
# Generation
# First     166
# Second    106
# Name: count, dtype: int64

# %%
pokemons.map(type)
# Out:
#         Short_name           Name         Type 1           Type 2  \
# #
# 1    <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 2    <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 3    <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 3    <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 4    <class 'str'>  <class 'str'>  <class 'str'>  <class 'float'>
# ..             ...            ...            ...              ...
# 719  <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 719  <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 720  <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 720  <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
# 721  <class 'str'>  <class 'str'>  <class 'str'>    <class 'str'>
#
#              Total             HP         Attack        Defense  \
# #
# 1    <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# ...

# %%
def uppercase(var: str):
    return var.upper()

# %%
pokemons = pokemons.applymap(str)
pokemons.applymap(uppercase)
# Out:
# C:\Users\maniu\AppData\Local\Temp\ipykernel_31788\113956347.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pokemons = pokemons.applymap(str)
# C:\Users\maniu\AppData\Local\Temp\ipykernel_31788\113956347.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pokemons.applymap(uppercase)
#                       Name   Type 1  Type 2 Total  HP Attack Defense Sp. Atk  \
# #
# 1                BULBASAUR    GRASS  POISON   318  45     49      49      65
# 2                  IVYSAUR    GRASS  POISON   405  60     62      63      80
# 3                 VENUSAUR    GRASS  POISON   525  80     82      83     100
# 3    VENUSAURMEGA VENUSAUR    GRASS  POISON   625  80    100     123     122
# 4               CHARMANDER     FIRE     NAN   309  39     52      43      60
# ..                     ...      ...     ...   ...  ..    ...     ...     ...
# ...

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      800 non-null    object
#  3   Total       800 non-null    object
#  4   HP          800 non-null    object
#  5   Attack      800 non-null    object
#  6   Defense     800 non-null    object
#  7   Sp. Atk     800 non-null    object
#  8   Sp. Def     800 non-null    object
#  9   Speed       800 non-null    object
#  10  Generation  800 non-null    object
#  11  Legendary   800 non-null    object
#  12  Score       800 non-null    object
# dtypes: object(13)
# memory usage: 87.5+ KB

# %%
pokemons.applymap(len)
# Out:
# C:\Users\maniu\AppData\Local\Temp\ipykernel_31788\4254828965.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pokemons.applymap(len)
#      Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1       9       5       6      3   2       2        2        2        2
# 2       7       5       6      3   2       2        2        2        2
# 3       8       5       6      3   2       2        2        3        3
# 3      21       5       6      3   2       3        3        3        3
# 4      10       4       3      3   2       2        2        2        2
# ..    ...     ...     ...    ...  ..     ...      ...      ...      ...
# 719     7       4       5      3   2       3        3        3        3
# 719    19       4       5      3   2       3        3        3        3
# 720    19       7       5      3   2       3        2        3        3
# 720    18       7       4      3   2       3        2        3        3
# ...

# %%
pokemons.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total         object
# HP            object
# Attack        object
# Defense       object
# Sp. Atk       object
# Sp. Def       object
# Speed         object
# Generation    object
# Legendary     object
# Score         object
# dtype: object

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      800 non-null    object
#  3   Total       800 non-null    object
#  4   HP          800 non-null    object
#  5   Attack      800 non-null    object
#  6   Defense     800 non-null    object
#  7   Sp. Atk     800 non-null    object
#  8   Sp. Def     800 non-null    object
#  9   Speed       800 non-null    object
#  10  Generation  800 non-null    object
#  11  Legendary   800 non-null    object
#  12  Score       800 non-null    object
# dtypes: object(13)
# memory usage: 87.5+ KB

# %%
pokemons=pd.read_csv('Pokemon.csv', index_col='#')

# %%
pokemons['Generation'] = pokemons['Generation'].astype('int8')
pokemons['Total'] = pokemons['Total'].astype('int16')
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int16
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int8
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int16(1), int64(6), int8(1), object(3)
# memory usage: 65.6+ KB

# %%
pokemons['Legendary'] = pokemons['Legendary'].astype('int8')
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int16
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int8
#  11  Legendary   800 non-null    int8
# dtypes: int16(1), int64(6), int8(2), object(3)
# memory usage: 65.6+ KB

# %%
pokemons['Legendary'].replace({1: 'Yes', 0: 'No'}, inplace=True)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary
# #
# ...

# %%
gen = pokemons['Generation'] == 2
#pokemons[gen]
#pokemons.where(pokemons['Generation'] == 2).dropna()
# Out:
#                         Name    Type 1    Type 2  Total     HP  Attack  \
# #
# 163                 Hoothoot    Normal    Flying  262.0   60.0    30.0
# 164                  Noctowl    Normal    Flying  442.0  100.0    50.0
# 165                   Ledyba       Bug    Flying  265.0   40.0    20.0
# 166                   Ledian       Bug    Flying  390.0   55.0    35.0
# 167                 Spinarak       Bug    Poison  250.0   40.0    60.0
# 168                  Ariados       Bug    Poison  390.0   70.0    90.0
# 169                   Crobat    Poison    Flying  535.0   85.0    90.0
# 170                 Chinchou     Water  Electric  330.0   75.0    38.0
# 171                  Lanturn     Water  Electric  460.0  125.0    58.0
# 174                Igglybuff    Normal     Fairy  210.0   90.0    30.0
# 176                  Togetic     Fairy    Flying  405.0   55.0    40.0
# 177                     Natu   Psychic    Flying  320.0   40.0    50.0
# ...

# %%
pokemons.agg({'Attack':'mean', 'Defense': 'max'})
# Out:
# Attack      79.00125
# Defense    230.00000
# dtype: float64

# %%
pokemons.agg({'Defense':['min','max','mean'], 'Speed': ['median', 'max']}).round(2)
# Out:
#         Defense  Speed
# min        5.00    NaN
# max      230.00  180.0
# mean      73.84    NaN
# median      NaN   65.0

# %%
pokemons.agg('max', numeric_only=True)
# Out:
# Total         780
# HP            255
# Attack        190
# Defense       230
# Sp. Atk       194
# Sp. Def       230
# Speed         180
# Generation      6
# dtype: int64

# %%
pokemons.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemons=pd.read_csv('Pokemon.csv', index_col='#')

# %%
legendary = pokemons['Legendary'].copy()
legendary
# Out:
# #
# 1      False
# 2      False
# 3      False
# 3      False
# 4      False
#        ...
# 719     True
# 719     True
# 720     True
# 720     True
# 721     True
# Name: Legendary, Length: 800, dtype: bool

# %%
legendary[0:3] = '???'
legendary
# Out:
# #
# 1        ???
# 2        ???
# 3        ???
# 3      False
# 4      False
#        ...
# 719     True
# 719     True
# 720     True
# 720     True
# 721     True
# Name: Legendary, Length: 800, dtype: object

# %%
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemons=pd.read_csv('Pokemon.csv')
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemons.set_index(['Name', 'Type 1'], inplace=True)

# %%
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Name                  Type 1
# Bulbasaur             Grass      1  Poison    318  45      49       49
# Ivysaur               Grass      2  Poison    405  60      62       63
# Venusaur              Grass      3  Poison    525  80      82       83
# VenusaurMega Venusaur Grass      3  Poison    625  80     100      123
# Charmander            Fire       4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Diancie               Rock     719   Fairy    600  50     100      150
# DiancieMega Diancie   Rock     719   Fairy    700  50     160      110
# HoopaHoopa Confined   Psychic  720   Ghost    600  80     110       60
# HoopaHoopa Unbound    Psychic  720    Dark    680  80     160       60
# Volcanion             Fire     721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemons.index
# Out:
# MultiIndex([(                'Bulbasaur',   'Grass'),
#             (                  'Ivysaur',   'Grass'),
#             (                 'Venusaur',   'Grass'),
#             (    'VenusaurMega Venusaur',   'Grass'),
#             (               'Charmander',    'Fire'),
#             (               'Charmeleon',    'Fire'),
#             (                'Charizard',    'Fire'),
#             ('CharizardMega Charizard X',    'Fire'),
#             ('CharizardMega Charizard Y',    'Fire'),
#             (                 'Squirtle',   'Water'),
#             ...
#             (                   'Noibat',  'Flying'),
#             (                  'Noivern',  'Flying'),
#             (                  'Xerneas',   'Fairy'),
#             (                  'Yveltal',    'Dark'),
#             (         'Zygarde50% Forme',  'Dragon'),
#             (                  'Diancie',    'Rock'),
#             (      'DiancieMega Diancie',    'Rock'),
# ...

# %%
pokemons.index.get_level_values(1)
# Out:
# Index(['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Fire',
#        'Fire', 'Water',
#        ...
#        'Flying', 'Flying', 'Fairy', 'Dark', 'Dragon', 'Rock', 'Rock',
#        'Psychic', 'Psychic', 'Fire'],
#       dtype='object', name='Type 1', length=800)

# %%
pokemons = pokemons.swaplevel()
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %%
pokemons.sort_values('Type 1')
# Out:
#                    #    Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Name
# Bug    Sewaddle  540     Grass    310   45      53       70       40       60
#        Pinsir    127       NaN    500   65     125      100       55       70
#        Burmy     412       NaN    224   40      29       45       29       45
#        Scyther   123    Flying    500   70     110       80       55       80
#        Joltik    595  Electric    319   50      47       50       57       50
# ...              ...       ...    ...  ...     ...      ...      ...      ...
# Water  Totodile  158       NaN    314   50      65       64       44       48
#        Basculin  550       NaN    460   70      92       65       80       55
#        Vaporeon  134       NaN    525  130      65       60      110       95
#        Panpour   515       NaN    316   50      53       48       53       48
#        Chinchou  170  Electric    330   75      38       38       56       56
#
# ...

# %%
pokemons=pd.read_csv('Pokemon.csv', index_col=['Type 1', 'Name'])
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %%
pokemons.loc['Grass'] # selecting by type
# Out:
#                          #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Poison    318   45      49       49       65
# Ivysaur                  2    Poison    405   60      62       63       80
# Venusaur                 3    Poison    525   80      82       83      100
# VenusaurMega Venusaur    3    Poison    625   80     100      123      122
# Oddish                  43    Poison    320   45      50       55       75
# ...                    ...       ...    ...  ...     ...      ...      ...
# Chespin                650       NaN    313   56      61       65       48
# Quilladin              651       NaN    405   61      78       95       56
# Chesnaught             652  Fighting    530   88     107      122       74
# Skiddo                 672       NaN    350   66      65       48       62
# Gogoat                 673       NaN    531  123     100       62       97
#
#                        Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemons.loc['Grass', 'Attack']    # selecting by type and specific column
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Oddish                    50
#                         ...
# Chespin                   61
# Quilladin                 78
# Chesnaught               107
# Skiddo                    65
# Gogoat                   100
# Name: Attack, Length: 70, dtype: int64

# %%
pokemons.loc[('Grass', 'Oddish'), 'Attack'] # selecting a column
# Out:
# 50

# %%
pokemons.loc[('Grass', 'Oddish'), ['Attack', 'Speed']]    # selecting multiple column
# Out:
# Attack    50
# Speed     30
# Name: (Grass, Oddish), dtype: int64

# %%
pokemons
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %%
pokemons.loc[('Grass', 'Fire'), ['Bulbasaur', 'Charmander'], :] 
# selecting multiple index, first tuple represents index, second list row name,(:) represents all data, important to mention
# Out:
#                    #  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Name
# Grass  Bulbasaur   1  Poison    318  45      49       49       65       65
# Fire   Charmander  4     NaN    309  39      52       43       60       50
#
#                    Speed  Generation  Legendary
# Type 1 Name
# Grass  Bulbasaur      45           1      False
# Fire   Charmander     65           1      False

# %%
pokemons.loc[:, 'Volcanion', :]  # by ignoring first index
# Out:
#           # Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Fire    721  Water    600  80     110      120      130       90     70
#
#         Generation  Legendary
# Type 1
# Fire             6       True

# %%
# get column value by ignoring first index
pokemons.loc[(slice(None), 'Bulbasaur'), 'Speed']
# Out:
# Type 1  Name
# Grass   Bulbasaur    45
# Name: Speed, dtype: int64

# %%
pokemon_test=pd.read_csv('Pokemon.csv', index_col=['Type 1', 'Name'])
pokemon_test
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1  Name
# ...

# %%
pokemon_test.sort_values('Type 1', inplace=True)
pokemon_test
# Out:
#                     #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Type 1 Name
# Bug    Sewaddle   540     Grass    310   45      53       70       40
#        Spinarak   167    Poison    250   40      60       40       40
#        Ledian     166    Flying    390   55      35       50       55
#        Nincada    290    Ground    266   31      45       90       30
#        Ledyba     165    Flying    265   40      20       30       40
# ...               ...       ...    ...  ...     ...      ...      ...
# Water  Gastrodon  423    Ground    475  111      83       68       92
#        Shellos    422       NaN    325   76      48       48       57
#        Floatzel   419       NaN    495   85     105       55       85
#        Clamperl   366       NaN    345   35      64       85       74
#        Chinchou   170  Electric    330   75      38       38       56
#
#                   Sp. Def  Speed  Generation  Legendary Strength
# Type 1 Name
# ...

# %%
selected_df = pokemon_test.loc['Fire']
selected_df = selected_df[selected_df.index.str.startswith('C')]
selected_df
# Out:
#                              #    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Charizard                    6    Flying    534  78      84       78      109
# CharizardMega Charizard X    6    Dragon    634  78     130      111      130
# CharizardMega Charizard Y    6    Flying    634  78     104       78      159
# Charmeleon                   5       NaN    405  58      64       58       80
# Charmander                   4       NaN    309  39      52       43       60
# Cyndaquil                  155       NaN    309  39      52       43       60
# Camerupt                   323    Ground    460  70     100       70      105
# Chimchar                   390       NaN    309  44      58       44       58
# Combusken                  256  Fighting    405  60      85       60       85
# CameruptMega Camerupt      323    Ground    560  70     120      100      145
#
#                            Sp. Def  Speed  Generation  Legendary Strength
# Name
# ...

# %%
pokemon_test.agg({'Attack':['max','min','mean'], 'Defense':['max','min','mean']}).round(1)
# Out:
#       Attack  Defense
# max    190.0    230.0
# min      5.0      5.0
# mean    79.0     73.8

# %%
def strength(attack: str):
    if attack > 100:
        return 'STRONG'
    else:
        return 'WEAK'

# %%
pokemon_test['Strength'] = pokemon_test['Attack'].apply(strength)
pokemon_test
# Out:
#                                  #  Type 2  Total  HP  Attack  Defense  \
# Type 1  Name
# Grass   Bulbasaur                1  Poison    318  45      49       49
#         Ivysaur                  2  Poison    405  60      62       63
#         Venusaur                 3  Poison    525  80      82       83
#         VenusaurMega Venusaur    3  Poison    625  80     100      123
# Fire    Charmander               4     NaN    309  39      52       43
# ...                            ...     ...    ...  ..     ...      ...
# Rock    Diancie                719   Fairy    600  50     100      150
#         DiancieMega Diancie    719   Fairy    700  50     160      110
# Psychic HoopaHoopa Confined    720   Ghost    600  80     110       60
#         HoopaHoopa Unbound     720    Dark    680  80     160       60
# Fire    Volcanion              721   Water    600  80     110      120
#
#                                Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Type 1  Name
# ...

# %%
reverse_name = pokemon_test.index.get_level_values('Name').str[::-1]
pokemon_test['Reversed'] = reverse_name
pokemon_test
# Out:
#                     #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Type 1 Name
# Bug    Sewaddle   540     Grass    310   45      53       70       40
#        Spinarak   167    Poison    250   40      60       40       40
#        Ledian     166    Flying    390   55      35       50       55
#        Nincada    290    Ground    266   31      45       90       30
#        Ledyba     165    Flying    265   40      20       30       40
# ...               ...       ...    ...  ...     ...      ...      ...
# Water  Gastrodon  423    Ground    475  111      83       68       92
#        Shellos    422       NaN    325   76      48       48       57
#        Floatzel   419       NaN    495   85     105       55       85
#        Clamperl   366       NaN    345   35      64       85       74
#        Chinchou   170  Electric    330   75      38       38       56
#
#                   Sp. Def  Speed  Generation  Legendary Strength   Reversed
# Type 1 Name
# ...

# %%
#pokemon_test.reset_index(drop=False, inplace=False)
pokemon_test.reset_index('Type 1')
# Out:
#           Type 1    #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Sewaddle     Bug  540     Grass    310   45      53       70       40
# Spinarak     Bug  167    Poison    250   40      60       40       40
# Ledian       Bug  166    Flying    390   55      35       50       55
# Nincada      Bug  290    Ground    266   31      45       90       30
# Ledyba       Bug  165    Flying    265   40      20       30       40
# ...          ...  ...       ...    ...  ...     ...      ...      ...
# Gastrodon  Water  423    Ground    475  111      83       68       92
# Shellos    Water  422       NaN    325   76      48       48       57
# Floatzel   Water  419       NaN    495   85     105       55       85
# Clamperl   Water  366       NaN    345   35      64       85       74
# Chinchou   Water  170  Electric    330   75      38       38       56
#
#            Sp. Def  Speed  Generation  Legendary Strength   Reversed
# Name
# ...

# %%
pokemon_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 800 entries, ('Bug', 'Sewaddle') to ('Water', 'Chinchou')
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Type 2      414 non-null    object
#  2   Total       800 non-null    int64
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
#  11  Strength    800 non-null    object
#  12  Reversed    800 non-null    object
# dtypes: bool(1), int64(9), object(3)
# memory usage: 117.4+ KB

# %%
pokemon_test.index.get_level_values('Name').str.upper()
# Out:
# Index(['SEWADDLE', 'SPINARAK', 'LEDIAN', 'NINCADA', 'LEDYBA', 'LEAVANNY',
#        'VENIPEDE', 'WHIRLIPEDE', 'SCOLIPEDE', 'VESPIQUEN',
#        ...
#        'LUMINEON', 'FINNEON', 'MANTINE', 'KINGDRA', 'SUICUNE', 'GASTRODON',
#        'SHELLOS', 'FLOATZEL', 'CLAMPERL', 'CHINCHOU'],
#       dtype='object', name='Name', length=800)

# %%
pokemon_test['Strength'].str.upper()
# Out:
# Type 1  Name
# Bug     Sewaddle       WEAK
#         Spinarak       WEAK
#         Ledian         WEAK
#         Nincada        WEAK
#         Ledyba         WEAK
#                       ...
# Water   Gastrodon      WEAK
#         Shellos        WEAK
#         Floatzel     STRONG
#         Clamperl       WEAK
#         Chinchou       WEAK
# Name: Strength, Length: 800, dtype: object

# %%
pokemon_test['Strength'].str[::-1]
# Out:
# Type 1  Name
# Bug     Sewaddle       KAEW
#         Spinarak       KAEW
#         Ledian         KAEW
#         Nincada        KAEW
#         Ledyba         KAEW
#                       ...
# Water   Gastrodon      KAEW
#         Shellos        KAEW
#         Floatzel     GNORTS
#         Clamperl       KAEW
#         Chinchou       KAEW
# Name: Strength, Length: 800, dtype: object

# %%
case_filter = pokemon_test.index.get_level_values('Name').str.contains('Xe', case=True)
pokemon_test[case_filter]
# Out:
#                   # Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Name
# Fairy  Xerneas  716    NaN    680  126     131       95      131       98
#
#                 Speed  Generation  Legendary Strength Reversed
# Type 1 Name
# Fairy  Xerneas     99           6       True   STRONG  saenreX

# %%
name_filter = pokemon_test['Name'].str.startswith('Do')
pokemon_test[name_filter]
# pokemon_test.reset_index(inplace=True)
# Out:
#      Type 1      Name    #  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 396  Ground   Donphan  232     NaN    500  90     120      120       60
# 445  Normal    Dodrio   85  Flying    460  60     110       70       60
# 455  Normal     Doduo   84  Flying    310  35      85       45       35
# 663   Steel  Doublade  680   Ghost    448  59     110      150       45
#
#      Sp. Def  Speed  Generation  Legendary Strength  Reversed
# 396       60     50           2      False   STRONG   nahpnoD
# 445       60    100           1      False   STRONG    oirdoD
# 455       35     75           1      False     WEAK     oudoD
# 663       49     35           6      False   STRONG  edalbuoD

# %%
name_filter = pokemon_test['Name'].str.endswith('chu')
pokemon_test[name_filter]
# Out:
#        Type 1     Name    # Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 134  Electric  Pikachu   25    NaN    320  35      55       40       50
# 139  Electric   Raichu   26    NaN    485  60      90       55       90
# 155  Electric    Pichu  172    NaN    205  20      40       15       35
#
#      Sp. Def  Speed  Generation  Legendary Strength Reversed
# 134       50     90           1      False     WEAK  uhcakiP
# 139       80    110           1      False     WEAK   uhciaR
# 155       35     60           2      False     WEAK    uhciP

# %%
pokemon_test['Type 1'] = pokemon_test['Type 1'].str.replace('Grass','Vegan',regex=False)
pokemon_test[pokemon_test['Type 1'] == 'Vegan']
# Out:
#     Type 1                   Name    #    Type 2  Total   HP  Attack  Defense  \
# 308  Vegan              Chikorita  152       NaN    318   45      49       65
# 309  Vegan             Bellsprout   69    Poison    300   50      75       35
# 310  Vegan  SceptileMega Sceptile  254    Dragon    630   70     110       75
# 311  Vegan             Victreebel   71    Poison    490   80     105       65
# 312  Vegan             Weepinbell   70    Poison    390   65      90       50
# ..     ...                    ...  ...       ...    ...  ...     ...      ...
# 373  Vegan              Ferroseed  597     Steel    305   44      50       91
# 374  Vegan              Amoonguss  591    Poison    464  114      85       70
# 375  Vegan                Foongus  590    Poison    294   69      55       45
# 376  Vegan                  Budew  406    Poison    280   40      30       35
# 377  Vegan               Virizion  640  Fighting    580   91      90       72
#
# ...

# %%
pokemon_test.columns
# Out:
# Index(['Type 1', '#', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Strength', 'Reversed'],
#       dtype='object')

# %%
#pokemon_test.set_index('Name', inplace=True)
# Out:
#           Type 1    #    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Sewaddle     Bug  540     Grass    310   45      53       70       40
# Spinarak     Bug  167    Poison    250   40      60       40       40
# Ledian       Bug  166    Flying    390   55      35       50       55
# Nincada      Bug  290    Ground    266   31      45       90       30
# Ledyba       Bug  165    Flying    265   40      20       30       40
# ...          ...  ...       ...    ...  ...     ...      ...      ...
# Gastrodon  Water  423    Ground    475  111      83       68       92
# Shellos    Water  422       NaN    325   76      48       48       57
# Floatzel   Water  419       NaN    495   85     105       55       85
# Clamperl   Water  366       NaN    345   35      64       85       74
# Chinchou   Water  170  Electric    330   75      38       38       56
#
#            Sp. Def  Speed  Generation  Legendary Strength   Reversed
# Name
# ...

# %%
pokemon_test.columns.str.upper()
# Out:
# Index(['TYPE 1', '#', 'TYPE 2', 'TOTAL', 'HP', 'ATTACK', 'DEFENSE', 'SP. ATK',
#        'SP. DEF', 'SPEED', 'GENERATION', 'LEGENDARY', 'STRENGTH', 'REVERSED'],
#       dtype='object')

# %%
pokemon_test.columns=pokemon_test.columns.str.upper()
pokemon_test
# Out:
#           TYPE 1    #    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# Name
# Sewaddle     Bug  540     Grass    310   45      53       70       40
# Spinarak     Bug  167    Poison    250   40      60       40       40
# Ledian       Bug  166    Flying    390   55      35       50       55
# Nincada      Bug  290    Ground    266   31      45       90       30
# Ledyba       Bug  165    Flying    265   40      20       30       40
# ...          ...  ...       ...    ...  ...     ...      ...      ...
# Gastrodon  Water  423    Ground    475  111      83       68       92
# Shellos    Water  422       NaN    325   76      48       48       57
# Floatzel   Water  419       NaN    495   85     105       55       85
# Clamperl   Water  366       NaN    345   35      64       85       74
# Chinchou   Water  170  Electric    330   75      38       38       56
#
#            SP. DEF  SPEED  GENERATION  LEGENDARY STRENGTH   REVERSED
# Name
# ...

# %%
pokemon_test.index.str[:5]
# Out:
# Index(['Sewad', 'Spina', 'Ledia', 'Ninca', 'Ledyb', 'Leava', 'Venip', 'Whirl',
#        'Scoli', 'Vespi',
#        ...
#        'Lumin', 'Finne', 'Manti', 'Kingd', 'Suicu', 'Gastr', 'Shell', 'Float',
#        'Clamp', 'Chinc'],
#       dtype='object', name='Name', length=800)

# %%
pokemon_test.index=pokemon_test.index.str[:5]
pokemon_test
# Out:
#       TYPE 1    #    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# Name
# Sewad    Bug  540     Grass    310   45      53       70       40       60
# Spina    Bug  167    Poison    250   40      60       40       40       40
# Ledia    Bug  166    Flying    390   55      35       50       55      110
# Ninca    Bug  290    Ground    266   31      45       90       30       30
# Ledyb    Bug  165    Flying    265   40      20       30       40       80
# ...      ...  ...       ...    ...  ...     ...      ...      ...      ...
# Gastr  Water  423    Ground    475  111      83       68       92       82
# Shell  Water  422       NaN    325   76      48       48       57       62
# Float  Water  419       NaN    495   85     105       55       85       50
# Clamp  Water  366       NaN    345   35      64       85       74       55
# Chinc  Water  170  Electric    330   75      38       38       56       56
#
#        SPEED  GENERATION  LEGENDARY STRENGTH   REVERSED
# ...
