# %%
import pandas as pd

# %%
titanic = pd.read_excel('titanic3.xls', index_col='name')
titanic
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
titanic.sort_index(inplace=True)

# %%
titanic.loc['Kelly, Mr. James']
# Out:
#                   pclass  survived   sex   age  sibsp  parch  ticket    fare  \
# name
# Kelly, Mr. James       3         0  male  34.5      0      0  330911  7.8292
# Kelly, Mr. James       3         0  male  44.0      0      0  363592  8.0500
#
#                  cabin embarked boat  body home.dest
# name
# Kelly, Mr. James   NaN        Q  NaN  70.0       NaN
# Kelly, Mr. James   NaN        S  NaN   NaN       NaN

# %%
titanic.loc['Allen, Miss. Elisabeth Walton': 'Allison, Miss. Helen Loraine']
# Out:
#                                 pclass  survived     sex      age  sibsp  \
# name
# Allen, Miss. Elisabeth Walton        1         1  female  29.0000      0
# Allen, Mr. William Henry             3         0    male  35.0000      0
# Allison, Master. Hudson Trevor       1         1    male   0.9167      1
# Allison, Miss. Helen Loraine         1         0  female   2.0000      1
#
#                                 parch  ticket      fare    cabin embarked  \
# name
# Allen, Miss. Elisabeth Walton       0   24160  211.3375       B5        S
# Allen, Mr. William Henry            0  373450    8.0500      NaN        S
# Allison, Master. Hudson Trevor      2  113781  151.5500  C22 C26        S
# Allison, Miss. Helen Loraine        2  113781  151.5500  C22 C26        S
#
#                                boat  body  \
# name
# Allen, Miss. Elisabeth Walton     2   NaN
# Allen, Mr. William Henry        NaN   NaN
# Allison, Master. Hudson Trevor   11   NaN
# ...

# %%
titanic.head(5)
# Out:
#                                   pclass  survived     sex   age  sibsp  \
# name
# Abbing, Mr. Anthony                    3         0    male  42.0      0
# Abbott, Master. Eugene Joseph          3         0    male  13.0      0
# Abbott, Mr. Rossmore Edward            3         0    male  16.0      1
# Abbott, Mrs. Stanton (Rosa Hunt)       3         1  female  35.0      1
# Abelseth, Miss. Karen Marie            3         1  female  16.0      0
#
#                                   parch     ticket   fare cabin embarked boat  \
# name
# Abbing, Mr. Anthony                   0  C.A. 5547   7.55   NaN        S  NaN
# Abbott, Master. Eugene Joseph         2  C.A. 2673  20.25   NaN        S  NaN
# Abbott, Mr. Rossmore Edward           1  C.A. 2673  20.25   NaN        S  NaN
# Abbott, Mrs. Stanton (Rosa Hunt)      1  C.A. 2673  20.25   NaN        S    A
# Abelseth, Miss. Karen Marie           0     348125   7.65   NaN        S   16
#
# ...

# %%
titanic.loc['Abbing, Mr. Anthony', 'ticket']
# Out:
# 'C.A. 5547'

# %%
titanic.loc['Abbing, Mr. Anthony', ['ticket', 'age']]
# Out:
# ticket    C.A. 5547
# age            42.0
# Name: Abbing, Mr. Anthony, dtype: object

# %%
titanic_df = pd.read_excel('titanic3.xls', usecols=['name','age','sex','pclass','fare'])
titanic_df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age      fare
# 0     29.0000  211.3375
# 1      0.9167  151.5500
# 2      2.0000  151.5500
# 3     30.0000  151.5500
# ...

# %%
titanic_df.iloc[2]
# Out:
# pclass                               1
# name      Allison, Miss. Helen Loraine
# sex                             female
# age                                2.0
# fare                            151.55
# Name: 2, dtype: object

# %%
titanic.iloc[10:15]
# Out:
#                                                 pclass  survived     sex  \
# name
# Adahl, Mr. Mauritz Nils Martin                       3         0    male
# Adams, Mr. John                                      3         0    male
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)       3         0  female
# Aks, Master. Philip Frank                            3         1    male
# Aks, Mrs. Sam (Leah Rosen)                           3         1  female
#
#                                                     age  sibsp  parch  ticket  \
# name
# Adahl, Mr. Mauritz Nils Martin                  30.0000      0      0  C 7076
# Adams, Mr. John                                 26.0000      0      0  341826
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0000      1      0    7546
# Aks, Master. Philip Frank                        0.8333      0      1  392091
# Aks, Mrs. Sam (Leah Rosen)                      18.0000      0      1  392091
#
# ...

# %%
titanic.iloc[0:10:2]
# Out:
#                                           pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                            3         0    male  42.0
# Abbott, Mr. Rossmore Edward                    3         0    male  16.0
# Abelseth, Miss. Karen Marie                    3         1  female  16.0
# Abelson, Mr. Samuel                            2         0    male  30.0
# Abrahamsson, Mr. Abraham August Johannes       3         1    male  20.0
#
#                                           sibsp  parch            ticket  \
# name
# Abbing, Mr. Anthony                           0      0         C.A. 5547
# Abbott, Mr. Rossmore Edward                   1      1         C.A. 2673
# Abelseth, Miss. Karen Marie                   0      0            348125
# Abelson, Mr. Samuel                           1      0         P/PP 3381
# Abrahamsson, Mr. Abraham August Johannes      0      0  SOTON/O2 3101284
#
# ...

# %%
titanic.iloc[[100,200,220]]
# Out:
#                                                     pclass  survived     sex  \
# name
# Bazzani, Miss. Albina                                    1         1  female
# Carlsson, Mr. August Sigfrid                             3         0    male
# Chaffee, Mrs. Herbert Fuller (Carrie Constance ...       1         1  female
#
#                                                      age  sibsp  parch  \
# name
# Bazzani, Miss. Albina                               32.0      0      0
# Carlsson, Mr. August Sigfrid                        28.0      0      0
# Chaffee, Mrs. Herbert Fuller (Carrie Constance ...  47.0      1      0
#
#                                                          ticket     fare  \
# name
# Bazzani, Miss. Albina                                     11813  76.2917
# Carlsson, Mr. August Sigfrid                             350042   7.7958
# Chaffee, Mrs. Herbert Fuller (Carrie Constance ...  W.E.P. 5734  61.1750
#
# ...

# %% [markdown]
# TO select specific column from the row. In iloc [row,col]

# %%
titanic_df.iloc[5,3]
# Out:
# 48.0

# %%
data1 = pd.Series(data=[10,20,30])
data2 = pd.Series(data=[1,2,3])
data1 + data2
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
data3 = pd.Series(data=[4,5,6,7])
data1 + data3
# Out:
# 0    14.0
# 1    25.0
# 2    36.0
# 3     NaN
# dtype: float64

# %%
dt1 = pd.DataFrame(data={'a':[1,2],'b':[3,4]})
dt2 = pd.DataFrame(data={'a':[10,20],'b':[30,40]})
dt1 + dt2
# Out:
#     a   b
# 0  11  33
# 1  22  44

# %%
dt3 = pd.DataFrame(data={'a':[4,5],'b':[3,4], 'c': [9,7]})
dt1 + dt3
# Out:
#    a  b   c
# 0  5  6 NaN
# 1  7  8 NaN

# %%
titanic_df['fare'] / 2
# Out:
# 0       105.66875
# 1        75.77500
# 2        75.77500
# 3        75.77500
# 4        75.77500
#           ...
# 1304      7.22710
# 1305      7.22710
# 1306      3.61250
# 1307      3.61250
# 1308      3.93750
# Name: fare, Length: 1309, dtype: float64

# %%
titanic_df['reduced'] = titanic_df['fare'] / 2
titanic_df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age      fare    reduced
# 0     29.0000  211.3375  105.66875
# 1      0.9167  151.5500   75.77500
# ...

# %%
titanic['sex'] == 'male'
# Out:
# name
# Abbing, Mr. Anthony                               True
# Abbott, Master. Eugene Joseph                     True
# Abbott, Mr. Rossmore Edward                       True
# Abbott, Mrs. Stanton (Rosa Hunt)                 False
# Abelseth, Miss. Karen Marie                      False
#                                                  ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)    False
# van Billiard, Master. James William               True
# van Billiard, Master. Walter John                 True
# van Billiard, Mr. Austin Blyler                   True
# van Melkebeke, Mr. Philemon                       True
# Name: sex, Length: 1309, dtype: bool

# %%
titanic[titanic['sex'] == 'male']
# Out:
#                                      pclass  survived   sex   age  sibsp  \
# name
# Abbing, Mr. Anthony                       3         0  male  42.0      0
# Abbott, Master. Eugene Joseph             3         0  male  13.0      0
# Abbott, Mr. Rossmore Edward               3         0  male  16.0      1
# Abelseth, Mr. Olaus Jorgensen             3         1  male  25.0      0
# Abelson, Mr. Samuel                       2         0  male  30.0      1
# ...                                     ...       ...   ...   ...    ...
# del Carlo, Mr. Sebastiano                 2         0  male  29.0      1
# van Billiard, Master. James William       3         0  male   NaN      1
# van Billiard, Master. Walter John         3         0  male  11.5      1
# van Billiard, Mr. Austin Blyler           3         0  male  40.5      0
# van Melkebeke, Mr. Philemon               3         0  male   NaN      0
#
#                                      parch         ticket     fare  cabin  \
# name
# ...

# %%
male_gender = titanic['sex'] == 'male'
first_class = titanic['pclass'] == 1
titanic[male_gender]
# Out:
#                                      pclass  survived   sex   age  sibsp  \
# name
# Abbing, Mr. Anthony                       3         0  male  42.0      0
# Abbott, Master. Eugene Joseph             3         0  male  13.0      0
# Abbott, Mr. Rossmore Edward               3         0  male  16.0      1
# Abelseth, Mr. Olaus Jorgensen             3         1  male  25.0      0
# Abelson, Mr. Samuel                       2         0  male  30.0      1
# ...                                     ...       ...   ...   ...    ...
# del Carlo, Mr. Sebastiano                 2         0  male  29.0      1
# van Billiard, Master. James William       3         0  male   NaN      1
# van Billiard, Master. Walter John         3         0  male  11.5      1
# van Billiard, Mr. Austin Blyler           3         0  male  40.5      0
# van Melkebeke, Mr. Philemon               3         0  male   NaN      0
#
#                                      parch         ticket     fare  cabin  \
# name
# ...

# %% [markdown]
# condition can be added as variable & filter to Dataframe
# multiple condition can be done
# only bitwise symbol will be used (ex: & , | , ~) it doesn't work (and,or,not)

# %%
survived = titanic['survived'] == 1
titanic[male_gender & first_class & survived & rich_kids]
# Out:
#                              pclass  survived   sex   age  sibsp  parch  \
# name
# Ryerson, Master. John Borie       1         1  male  13.0      2      2
#
#                                ticket     fare            cabin embarked boat  \
# name
# Ryerson, Master. John Borie  PC 17608  262.375  B57 B59 B63 B66        C    4
#
#                              body                        home.dest
# name
# Ryerson, Master. John Borie   NaN  Haverford, PA / Cooperstown, NY

# %%
rich_kids = (titanic['age'] < 21) & (titanic['fare'] > 200)
rich_data = titanic[rich_kids]
rich_data.nlargest(n=3, columns=['age','fare'])
# Out:
#                                                    pclass  survived     sex  \
# name
# Fortune, Mr. Charles Alexander                          1         0    male
# Ryerson, Miss. Emily Borie                              1         1  female
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)       1         1  female
#
#                                                     age  sibsp  parch  \
# name
# Fortune, Mr. Charles Alexander                     19.0      3      2
# Ryerson, Miss. Emily Borie                         18.0      2      2
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0      1      0
#
#                                                      ticket     fare  \
# name
# Fortune, Mr. Charles Alexander                        19950  263.000
# Ryerson, Miss. Emily Borie                         PC 17608  262.375
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)  PC 17757  227.525
#
# ...

# %%
female_gender = titanic['sex'] == 'female'
titanic[female_gender & survived]
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# Abelson, Mrs. Samuel (Hannah Wizosky)               2         1  female  28.0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)           3         1  female  18.0
# Aks, Mrs. Sam (Leah Rosen)                          3         1  female  18.0
# ...                                               ...       ...     ...   ...
# Wright, Miss. Marion                                2         1  female  26.0
# Yasbeck, Mrs. Antoni (Selini Alexander)             3         1  female  15.0
# Young, Miss. Marie Grice                            1         1  female  36.0
# de Messemaeker, Mrs. Guillaume Joseph (Emma)        3         1  female  36.0
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
#
# ...

# %%
#titanic[(titanic['age'] <= 21 | female_gender) & survived]
titanic.loc[(titanic['age'] <= 21 | female_gender) & survived]
# Out:
#                                          pclass  survived     sex     age  \
# name
# Aks, Master. Philip Frank                     3         1    male  0.8333
# Allison, Master. Hudson Trevor                1         1    male  0.9167
# Baclini, Miss. Eugenie                        3         1  female  0.7500
# Baclini, Miss. Helene Barbara                 3         1  female  0.7500
# Becker, Master. Richard F                     2         1    male  1.0000
# Caldwell, Master. Alden Gates                 2         1    male  0.8333
# Dean, Master. Bertram Vere                    3         1    male  1.0000
# Dean, Miss. Elizabeth Gladys "Millvina"       3         1  female  0.1667
# Hamalainen, Master. Viljo                     2         1    male  0.6667
# Johnson, Miss. Eleanor Ileen                  3         1  female  1.0000
# Laroche, Miss. Louise                         2         1  female  1.0000
# Mallet, Master. Andre                         2         1    male  1.0000
# ...

# %%
upper_age = titanic['age'] >= 20
lower_age = titanic['age'] <= 25
titanic[upper_age & lower_age]
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abelseth, Mr. Olaus Jorgensen                       3         1    male  25.0
# Abrahamsson, Mr. Abraham August Johannes            3         1    male  20.0
# Alhomaki, Mr. Ilmari Rudolf                         3         0    male  20.0
# Ali, Mr. Ahmed                                      3         0    male  24.0
# Ali, Mr. William                                    3         0    male  25.0
# ...                                               ...       ...     ...   ...
# Willard, Miss. Constance                            1         1  female  21.0
# Williams, Mr. Richard Norris II                     1         1    male  21.0
# Windelov, Mr. Einar                                 3         0    male  21.0
# Yrois, Miss. Henriette ("Mrs Harbeck")              2         0  female  24.0
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
#
# ...

# %%
Young = titanic['age'].between(20, 22)
titanic[Young]
# Out:
#                                           pclass  survived     sex   age  \
# name
# Abrahamsson, Mr. Abraham August Johannes       3         1    male  20.0
# Alhomaki, Mr. Ilmari Rudolf                    3         0    male  20.0
# Andreasson, Mr. Paul Edvin                     3         0    male  20.0
# Assaf, Mr. Gerios                              3         0    male  21.0
# Baccos, Mr. Raffull                            3         0    male  20.0
# ...                                          ...       ...     ...   ...
# White, Mr. Richard Frasar                      1         0    male  21.0
# Wiklund, Mr. Karl Johan                        3         0    male  21.0
# Willard, Miss. Constance                       1         1  female  21.0
# Williams, Mr. Richard Norris II                1         1    male  21.0
# Windelov, Mr. Einar                            3         0    male  21.0
#
#                                           sibsp  parch            ticket  \
# name
# ...

# %% [markdown]
# by adding inclusive, by starts and ends also included
# in inclusive - list of keywords - left, right, neither, both

# %%
young_dt = titanic['age'].between(20,22 , inclusive='both')
titanic[young_dt]
# Out:
#                                           pclass  survived     sex   age  \
# name
# Abrahamsson, Mr. Abraham August Johannes       3         1    male  20.0
# Alhomaki, Mr. Ilmari Rudolf                    3         0    male  20.0
# Andreasson, Mr. Paul Edvin                     3         0    male  20.0
# Assaf, Mr. Gerios                              3         0    male  21.0
# Baccos, Mr. Raffull                            3         0    male  20.0
# ...                                          ...       ...     ...   ...
# White, Mr. Richard Frasar                      1         0    male  21.0
# Wiklund, Mr. Karl Johan                        3         0    male  21.0
# Willard, Miss. Constance                       1         1  female  21.0
# Williams, Mr. Richard Norris II                1         1    male  21.0
# Windelov, Mr. Einar                            3         0    male  21.0
#
#                                           sibsp  parch            ticket  \
# name
# ...

# %%
first_class = titanic['pclass'] == 1
second_class = titanic['pclass'] == 2
titanic[first_class | second_class]
# Out:
#                                                pclass  survived     sex  \
# name
# Abelson, Mr. Samuel                                 2         0    male
# Abelson, Mrs. Samuel (Hannah Wizosky)               2         1  female
# Aldworth, Mr. Charles Augustus                      2         0    male
# Allen, Miss. Elisabeth Walton                       1         1  female
# Allison, Master. Hudson Trevor                      1         1    male
# ...                                               ...       ...     ...
# Young, Miss. Marie Grice                            1         1  female
# Yrois, Miss. Henriette ("Mrs Harbeck")              2         0  female
# de Brito, Mr. Jose Joaquim                          2         0    male
# del Carlo, Mr. Sebastiano                           2         0    male
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female
#
#                                                    age  sibsp  parch  \
# name
# ...

# %% [markdown]
# isin - check the list of values present
# isnull  - return null value
# notnull - return not null value

# %%
titanic['pclass'].isin([1,2])
# Out:
# name
# Abbing, Mr. Anthony                              False
# Abbott, Master. Eugene Joseph                    False
# Abbott, Mr. Rossmore Edward                      False
# Abbott, Mrs. Stanton (Rosa Hunt)                 False
# Abelseth, Miss. Karen Marie                      False
#                                                  ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)     True
# van Billiard, Master. James William              False
# van Billiard, Master. Walter John                False
# van Billiard, Mr. Austin Blyler                  False
# van Melkebeke, Mr. Philemon                      False
# Name: pclass, Length: 1309, dtype: bool

# %%
unknown_age = titanic['age'].isnull()
titanic[unknown_age]
# Out:
#                                      pclass  survived     sex  age  sibsp  \
# name
# Baumann, Mr. John D                       1         0    male  NaN      0
# Betros, Master. Seman                     3         0    male  NaN      0
# Boulos, Mr. Hanna                         3         0    male  NaN      0
# Boulos, Mrs. Joseph (Sultana)             3         0  female  NaN      0
# Bourke, Miss. Mary                        3         0  female  NaN      0
# ...                                     ...       ...     ...  ...    ...
# Yousif, Mr. Wazli                         3         0    male  NaN      0
# Yousseff, Mr. Gerious                     3         0    male  NaN      0
# Zabour, Miss. Thamine                     3         0  female  NaN      1
# van Billiard, Master. James William       3         0    male  NaN      1
# van Melkebeke, Mr. Philemon               3         0    male  NaN      0
#
# ...

# %%
titanic['age'].notnull()
# Out:
# name
# Abbing, Mr. Anthony                               True
# Abbott, Master. Eugene Joseph                     True
# Abbott, Mr. Rossmore Edward                       True
# Abbott, Mrs. Stanton (Rosa Hunt)                  True
# Abelseth, Miss. Karen Marie                       True
#                                                  ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)     True
# van Billiard, Master. James William              False
# van Billiard, Master. Walter John                 True
# van Billiard, Mr. Austin Blyler                   True
# van Melkebeke, Mr. Philemon                      False
# Name: age, Length: 1309, dtype: bool

# %% [markdown]
# Rename the column by method name rename

# %%
titanic.rename(columns={'fare': 'Ticket Price'}, inplace=True)
titanic
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic.rename({'home.dest':'Destination'}, axis=1)
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic.index.name = 'Passenger'
titanic
# Out:
#                                                pclass  survived     sex   age  \
# Passenger
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic_test = pd.read_excel('titanic3.xls', index_col='name')
titanic_test.drop(['home.dest','embarked','sibsp','parch'], axis=1)
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %%
not_survive = titanic_test['survived'] == 0
survive = titanic_test['survived'] == 1
titanic_test = titanic_test[survive]
titanic_test
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Anderson, Mr. Harry                                   1         1    male
# Andrews, Miss. Kornelia Theodosia                     1         1  female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1         1  female
# ...                                                 ...       ...     ...
# Turkula, Mrs. (Hedwig)                                3         1  female
# Vartanian, Mr. David                                  3         1    male
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3         1  female
# Wilkes, Mrs. James (Ellen Needs)                      3         1  female
# Yasbeck, Mrs. Antoni (Selini Alexander)               3         1  female
#
#                                                      age  sibsp  parch  \
# ...

# %%
titanic_test.drop(columns=['body', 'survived'], inplace=True)
titanic_test
# Out:
#                                                  pclass     sex      age  \
# name
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Anderson, Mr. Harry                                   1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                     1  female  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female  53.0000
# ...                                                 ...     ...      ...
# Turkula, Mrs. (Hedwig)                                3  female  63.0000
# Vartanian, Mr. David                                  3    male  22.0000
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3  female  38.0000
# Wilkes, Mrs. James (Ellen Needs)                      3  female  47.0000
# Yasbeck, Mrs. Antoni (Selini Alexander)               3  female  15.0000
#
#                                                  sibsp  parch  ticket  \
# name
# ...

# %%
third_class = titanic_test['pclass'] == 3
titanic_test.loc[third_class, 'fare'].max()
# Out:
# 56.4958

# %%
titanic_test.index.name = 'Passenger'
titanic_test
# Out:
#                                                  pclass     sex      age  \
# Passenger
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Anderson, Mr. Harry                                   1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                     1  female  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female  53.0000
# ...                                                 ...     ...      ...
# Turkula, Mrs. (Hedwig)                                3  female  63.0000
# Vartanian, Mr. David                                  3    male  22.0000
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3  female  38.0000
# Wilkes, Mrs. James (Ellen Needs)                      3  female  47.0000
# Yasbeck, Mrs. Antoni (Selini Alexander)               3  female  15.0000
#
#                                                  sibsp  parch  ticket  \
# ...

# %%
coffee_class = titanic_test['pclass'].isin([1,2])
titanic_test['Free Coffee'] = 0
titanic_test.loc[coffee_class, 'Free Coffee'] = 1
titanic_test
# Out:
#                                                  pclass     sex      age  \
# Passenger
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Anderson, Mr. Harry                                   1    male  48.0000
# Andrews, Miss. Kornelia Theodosia                     1  female  63.0000
# Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female  53.0000
# ...                                                 ...     ...      ...
# Turkula, Mrs. (Hedwig)                                3  female  63.0000
# Vartanian, Mr. David                                  3    male  22.0000
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3  female  38.0000
# Wilkes, Mrs. James (Ellen Needs)                      3  female  47.0000
# Yasbeck, Mrs. Antoni (Selini Alexander)               3  female  15.0000
#
#                                                  sibsp  parch  ticket  \
# ...

# %%
titanic_test[~coffee_class][['pclass','Free Coffee']]
# Out:
#                                                  pclass  Free Coffee
# Passenger
# Abbott, Mrs. Stanton (Rosa Hunt)                      3            0
# Abelseth, Miss. Karen Marie                           3            0
# Abelseth, Mr. Olaus Jorgensen                         3            0
# Abrahamsson, Mr. Abraham August Johannes              3            0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)             3            0
# ...                                                 ...          ...
# Turkula, Mrs. (Hedwig)                                3            0
# Vartanian, Mr. David                                  3            0
# Whabee, Mrs. George Joseph (Shawneene Abi-Saab)       3            0
# Wilkes, Mrs. James (Ellen Needs)                      3            0
# Yasbeck, Mrs. Antoni (Selini Alexander)               3            0
#
# [181 rows x 2 columns]

# %%
titanic_test.loc[:, ['Free Coffee', 'pclass']].value_counts()
# Out:
# Free Coffee  pclass
# 1            1         200
# 0            3         181
# 1            2         119
# Name: count, dtype: int64
