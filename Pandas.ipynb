# %%
import pandas as pd

richest = pd.read_csv('TopRichestInWorld.csv', usecols=['Name', 'Age'], index_col='Name').squeeze()

# %%
richest
# Out:
# Name
# Elon Musk                   50
# Jeff Bezos                  58
# Bernard Arnault & family    73
# Bill Gates                  66
# Warren Buffett              91
#                             ..
# Vladimir Potanin            61
# Harold Hamm & family        76
# Sun Piaoyang                63
# Luo Liguo & family          66
# Peter Woo                   75
# Name: Age, Length: 101, dtype: int64

# %%
oldest = richest.idxmax()
oldest
# Out:
# 'Lee Shau Kee'

# %%
richest[oldest]
# Out:
# 94

# %%
richest.sort_values(ascending=False)
# Out:
# Name
# Lee Shau Kee               94
# Li Ka-shing                93
# Warren Buffett             91
# Rupert Murdoch & family    91
# Leonard Lauder             89
#                            ..
# Yang Huiyan & family       40
# Guillaume Pousaz           40
# Zhang Yiming               38
# Mark Zuckerberg            37
# Sam Bankman-Fried          30
# Name: Age, Length: 101, dtype: int64

# %%
youngest = richest.idxmin()
youngest
# Out:
# 'Sam Bankman-Fried'

# %%
richest[youngest]
# Out:
# 30

# %%
richest.mean().round(2)
# Out:
# 67.12

# %%
richest.to_csv('richpeople.csv')

# %%
pd.read_csv('richpeople.csv')
# Out:
#                          Name  Age
# 0                   Elon Musk   50
# 1                  Jeff Bezos   58
# 2    Bernard Arnault & family   73
# 3                  Bill Gates   66
# 4              Warren Buffett   91
# ..                        ...  ...
# 96           Vladimir Potanin   61
# 97       Harold Hamm & family   76
# 98               Sun Piaoyang   63
# 99         Luo Liguo & family   66
# 100                 Peter Woo   75
#
# [101 rows x 2 columns]

# %%
richest = pd.read_csv('TopRichestInWorld.csv')

# %%
richest.shape
# Out:
# (101, 6)

# %%
richest.size
# Out:
# 606

# %%
richest.index
# Out:
# RangeIndex(start=0, stop=101, step=1)

# %%
richest.columns
# Out:
# Index(['Name', 'NetWorth', 'Age', 'Country/Territory', 'Source', 'Industry'], dtype='object')

# %%
richest.axes
# Out:
# [RangeIndex(start=0, stop=101, step=1),
#  Index(['Name', 'NetWorth', 'Age', 'Country/Territory', 'Source', 'Industry'], dtype='object')]

# %%
richest.dtypes
# Out:
# Name                 object
# NetWorth             object
# Age                   int64
# Country/Territory    object
# Source               object
# Industry             object
# dtype: object

# %%
richest.values
# Out:
# array([['Elon Musk', '$219,000,000,000', 50, 'United States',
#         'Tesla, SpaceX', 'Automotive'],
#        ['Jeff Bezos', '$171,000,000,000', 58, 'United States', 'Amazon',
#         'Technology'],
#        ['Bernard Arnault & family', '$158,000,000,000', 73, 'France',
#         'LVMH', 'Fashion & Retail'],
#        ['Bill Gates', '$129,000,000,000', 66, 'United States',
#         'Microsoft', 'Technology'],
#        ['Warren Buffett', '$118,000,000,000', 91, 'United States',
#         'Berkshire Hathaway', 'Finance & Investments'],
#        ['Larry Page', '$111,000,000,000', 49, 'United States', 'Google',
#         'Technology'],
#        ['Sergey Brin', '$107,000,000,000', 48, 'United States', 'Google',
#         'Technology'],
#        ['Larry Ellison', '$106,000,000,000', 77, 'United States',
#         'software', 'Technology'],
#        ['Steve Ballmer', '$91,400,000,000', 66, 'United States',
#         'Microsoft', 'Technology'],
# ...

# %%
richest.describe().round(2)
# Out:
#           Age
# count  101.00
# mean    67.12
# std     13.89
# min     30.00
# 25%     57.00
# 50%     67.00
# 75%     77.00
# max     94.00

# %%
richest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               101 non-null    object
#  1   NetWorth           101 non-null    object
#  2   Age                101 non-null    int64
#  3   Country/Territory  101 non-null    object
#  4   Source             101 non-null    object
#  5   Industry           101 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.9+ KB

# %%
movie_data = pd.read_csv('imdb_top_1000.csv')
movie_data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
columns = ['Series_Title', 'IMDB_Rating', 'Genre', 'Released_Year', 'No_of_Votes', 'Gross']
movie_clean_data = pd.read_csv('imdb_top_1000.csv', usecols=columns)
movie_clean_data
# Out:
#                  Series_Title Released_Year                     Genre  \
# 0    The Shawshank Redemption          1994                     Drama
# 1               The Godfather          1972              Crime, Drama
# 2             The Dark Knight          2008      Action, Crime, Drama
# 3      The Godfather: Part II          1974              Crime, Drama
# 4                12 Angry Men          1957              Crime, Drama
# ..                        ...           ...                       ...
# 995    Breakfast at Tiffany's          1961    Comedy, Drama, Romance
# 996                     Giant          1956            Drama, Western
# 997     From Here to Eternity          1953       Drama, Romance, War
# 998                  Lifeboat          1944                Drama, War
# 999              The 39 Steps          1935  Crime, Mystery, Thriller
#
#      IMDB_Rating  No_of_Votes        Gross
# 0            9.3      2343110   28,341,469
# ...

# %%
movie_clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Genre          1000 non-null   object
#  3   IMDB_Rating    1000 non-null   float64
#  4   No_of_Votes    1000 non-null   int64
#  5   Gross          831 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 47.0+ KB

# %%
movie_clean_data.describe().round()
# Out:
#        IMDB_Rating  No_of_Votes
# count       1000.0       1000.0
# mean           8.0     273693.0
# std            0.0     327373.0
# min            8.0      25088.0
# 25%            8.0      55526.0
# 50%            8.0     138548.0
# 75%            8.0     374161.0
# max            9.0    2343110.0

# %%
movie_clean_data['Gross'] = movie_clean_data['Gross'].astype(str).str.replace(',', '')

# %%
movie_clean_data['Gross'].fillna(0)
movie_clean_data['Gross'] = movie_clean_data['Gross'].astype('int64')
movie_clean_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[278], line 2
#       1 movie_clean_data['Gross'].fillna(0)
# ----> 2 movie_clean_data['Gross'] = movie_clean_data['Gross'].astype('int64')
#       3 movie_clean_data
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
movie_clean_data.describe().round()
# Out:
#        IMDB_Rating  No_of_Votes
# count       1000.0       1000.0
# mean           8.0     273693.0
# std            0.0     327373.0
# min            8.0      25088.0
# 25%            8.0      55526.0
# 50%            8.0     138548.0
# 75%            8.0     374161.0
# max            9.0    2343110.0

# %%
movie_clean_data.count()
# Out:
# Series_Title     1000
# Released_Year    1000
# Genre            1000
# IMDB_Rating      1000
# No_of_Votes      1000
# Gross            1000
# dtype: int64

# %%
movie_clean_data.mean(numeric_only=True).round()
# Out:
# IMDB_Rating         8.0
# No_of_Votes    273693.0
# dtype: float64

# %%
movie_clean_data.max(numeric_only=True).round()
# Out:
# IMDB_Rating          9.0
# No_of_Votes    2343110.0
# dtype: float64

# %%
movie_clean_data.min(numeric_only=True).round()
# Out:
# IMDB_Rating        8.0
# No_of_Votes    25088.0
# dtype: float64

# %%
movie_clean_data.quantile(q=.5, numeric_only=True).round(2)
# Out:
# IMDB_Rating         7.9
# No_of_Votes    138548.5
# Name: 0.5, dtype: float64

# %%
movie_clean_data.describe(include=['O'])
# Out:
#        Series_Title Released_Year  Genre Gross
# count          1000          1000   1000  1000
# unique          999           100    202   824
# top        Drishyam          2014  Drama   nan
# freq              2            32     85   169

# %%
movie_clean_data[movie_clean_data['Series_Title'].duplicated(keep=False) ==  True]
# Out:
#     Series_Title Released_Year                   Genre  IMDB_Rating  \
# 87      Drishyam          2013  Crime, Drama, Thriller          8.3
# 136     Drishyam          2015   Crime, Drama, Mystery          8.2
#
#      No_of_Votes   Gross
# 87         30722     nan
# 136        70367  739478

# %%
movie_clean_data.nlargest(n=10, columns=['No_of_Votes'])
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 2                                     The Dark Knight          2008
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 6                                        Pulp Fiction          1994
# 11                                       Forrest Gump          1994
# 14                                         The Matrix          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 5       The Lord of the Rings: The Return of the King          2003
# 1                                       The Godfather          1972
#
#                         Genre  IMDB_Rating  No_of_Votes      Gross
# 0                       Drama          9.3      2343110   28341469
# 2        Action, Crime, Drama          9.0      2303232  534858444
# ...

# %%
movie_clean_data.nlargest(n=10, columns=['IMDB_Rating', 'No_of_Votes'])
# Out:
#                                     Series_Title Released_Year  \
# 0                       The Shawshank Redemption          1994
# 1                                  The Godfather          1972
# 2                                The Dark Knight          2008
# 3                         The Godfather: Part II          1974
# 4                                   12 Angry Men          1957
# 6                                   Pulp Fiction          1994
# 5  The Lord of the Rings: The Return of the King          2003
# 7                               Schindler's List          1993
# 8                                      Inception          2010
# 9                                     Fight Club          1999
#
#                        Genre  IMDB_Rating  No_of_Votes      Gross
# 0                      Drama          9.3      2343110   28341469
# 1               Crime, Drama          9.2      1620367  134966411
# 2       Action, Crime, Drama          9.0      2303232  534858444
# ...

# %%
movie_clean_data.nsmallest(n=10, columns=['IMDB_Rating', 'No_of_Votes'])
# Out:
#             Series_Title Released_Year                         Genre  \
# 989     The Long Goodbye          1973          Comedy, Crime, Drama
# 998             Lifeboat          1944                    Drama, War
# 971    Omohide poro poro          1991     Animation, Drama, Romance
# 981       On Golden Pond          1981                         Drama
# 880             Nelyubov          2017                         Drama
# 990         Giù la testa          1971           Drama, War, Western
# 920  The Secret of Kells          2009  Animation, Adventure, Family
# 984     The Muppet Movie          1979     Adventure, Comedy, Family
# 986       Watership Down          1978   Animation, Adventure, Drama
# 996                Giant          1956                Drama, Western
#
#      IMDB_Rating  No_of_Votes      Gross
# 989          7.6        26337     959000
# 998          7.6        26471        nan
# 971          7.6        27071     453243
# ...

# %%
movie_clean_data.nlargest(n=10, columns=['No_of_Votes'], keep='first')
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 2                                     The Dark Knight          2008
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 6                                        Pulp Fiction          1994
# 11                                       Forrest Gump          1994
# 14                                         The Matrix          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 5       The Lord of the Rings: The Return of the King          2003
# 1                                       The Godfather          1972
#
#                         Genre  IMDB_Rating  No_of_Votes      Gross
# 0                       Drama          9.3      2343110   28341469
# 2        Action, Crime, Drama          9.0      2303232  534858444
# ...

# %%
movie_clean_data.set_index('Series_Title', drop=True, inplace=True)

# %%
movie_clean_data
# Out:
#                          Released_Year                     Genre  IMDB_Rating  \
# Series_Title
# The Shawshank Redemption          1994                     Drama          9.3
# The Godfather                     1972              Crime, Drama          9.2
# The Dark Knight                   2008      Action, Crime, Drama          9.0
# The Godfather: Part II            1974              Crime, Drama          9.0
# 12 Angry Men                      1957              Crime, Drama          9.0
# ...                                ...                       ...          ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance          7.6
# Giant                             1956            Drama, Western          7.6
# From Here to Eternity             1953       Drama, Romance, War          7.6
# Lifeboat                          1944                Drama, War          7.6
# The 39 Steps                      1935  Crime, Mystery, Thriller          7.6
#
# ...

# %%
movie_clean_data.index.name='Title'
movie_clean_data
# Out:
#                          Released_Year                     Genre  IMDB_Rating  \
# Title
# The Shawshank Redemption          1994                     Drama          9.3
# The Godfather                     1972              Crime, Drama          9.2
# The Dark Knight                   2008      Action, Crime, Drama          9.0
# The Godfather: Part II            1974              Crime, Drama          9.0
# 12 Angry Men                      1957              Crime, Drama          9.0
# ...                                ...                       ...          ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance          7.6
# Giant                             1956            Drama, Western          7.6
# From Here to Eternity             1953       Drama, Romance, War          7.6
# Lifeboat                          1944                Drama, War          7.6
# The 39 Steps                      1935  Crime, Mystery, Thriller          7.6
#
# ...

# %%
movie_clean_data
# Out:
#                          Released_Year                     Genre  IMDB_Rating  \
# Title
# The Shawshank Redemption          1994                     Drama          9.3
# The Godfather                     1972              Crime, Drama          9.2
# The Dark Knight                   2008      Action, Crime, Drama          9.0
# The Godfather: Part II            1974              Crime, Drama          9.0
# 12 Angry Men                      1957              Crime, Drama          9.0
# ...                                ...                       ...          ...
# Breakfast at Tiffany's            1961    Comedy, Drama, Romance          7.6
# Giant                             1956            Drama, Western          7.6
# From Here to Eternity             1953       Drama, Romance, War          7.6
# Lifeboat                          1944                Drama, War          7.6
# The 39 Steps                      1935  Crime, Mystery, Thriller          7.6
#
# ...

# %%
movie_clean_data.reset_index(drop=False, inplace=False)
# Out:
#                         Title Released_Year                     Genre  \
# 0    The Shawshank Redemption          1994                     Drama
# 1               The Godfather          1972              Crime, Drama
# 2             The Dark Knight          2008      Action, Crime, Drama
# 3      The Godfather: Part II          1974              Crime, Drama
# 4                12 Angry Men          1957              Crime, Drama
# ..                        ...           ...                       ...
# 995    Breakfast at Tiffany's          1961    Comedy, Drama, Romance
# 996                     Giant          1956            Drama, Western
# 997     From Here to Eternity          1953       Drama, Romance, War
# 998                  Lifeboat          1944                Drama, War
# 999              The 39 Steps          1935  Crime, Mystery, Thriller
#
#      IMDB_Rating  No_of_Votes      Gross
# 0            9.3      2343110   28341469
# 1            9.2      1620367  134966411
# ...

# %%
movie_dt=pd.read_csv('imdb_top_1000.csv')
movie_dt.drop(columns=['Certificate','Overview','Poster_Link'],inplace=True)
movie_dt
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# 1                Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0        84.0     Christopher Nolan
# ...

# %%
movie_dt.drop(labels=[0,1,2])
# Out:
#                                       Series_Title Released_Year  Runtime  \
# 3                           The Godfather: Part II          1974  202 min
# 4                                     12 Angry Men          1957   96 min
# 5    The Lord of the Rings: The Return of the King          2003  201 min
# 6                                     Pulp Fiction          1994  154 min
# 7                                 Schindler's List          1993  195 min
# ..                                             ...           ...      ...
# 995                         Breakfast at Tiffany's          1961  115 min
# 996                                          Giant          1956  201 min
# 997                          From Here to Eternity          1953  118 min
# 998                                       Lifeboat          1944   97 min
# 999                                   The 39 Steps          1935   86 min
#
#                          Genre  IMDB_Rating  Meta_score              Director  \
# ...

# %%
movie_dt.drop([4,5])
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 6                Pulp Fiction          1994  154 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# 1                Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0        84.0     Christopher Nolan
# ...

# %%
movie_dt.drop(['Star1', 'Meta_score'], axis=1)
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating              Director  \
# 0                       Drama          9.3        Frank Darabont
# 1                Crime, Drama          9.2  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0     Christopher Nolan
# ...

# %%
movie_dt['Watched']=False
movie_dt
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# 1                Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0        84.0     Christopher Nolan
# ...

# %%
movie_dt.insert(loc=2, column='My_Rating', value=None)

# %%
movie_dt.drop(columns=['My_rating'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[302], line 1
# ----> 1 movie_dt.drop(columns=['My_rating'], inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
movie_dt

# %%
movie_dt.nsmallest(columns=['IMDB_Rating','No_of_Votes'],n=1)
# Out:
#          Series_Title Released_Year My_Rating  Runtime                 Genre  \
# 989  The Long Goodbye          1973      None  112 min  Comedy, Crime, Drama
#
#      IMDB_Rating  Meta_score       Director          Star1              Star2  \
# 989          7.6        87.0  Robert Altman  Elliott Gould  Nina van Pallandt
#
#                Star3        Star4  No_of_Votes    Gross  Watched
# 989  Sterling Hayden  Mark Rydell        26337  959,000    False

# %%
movie_dt.nlargest(columns=['IMDB_Rating','No_of_Votes'],n=1)
# Out:
#                Series_Title Released_Year My_Rating  Runtime  Genre  \
# 0  The Shawshank Redemption          1994      None  142 min  Drama
#
#    IMDB_Rating  Meta_score        Director        Star1           Star2  \
# 0          9.3        80.0  Frank Darabont  Tim Robbins  Morgan Freeman
#
#         Star3           Star4  No_of_Votes       Gross  Watched
# 0  Bob Gunton  William Sadler      2343110  28,341,469    False

# %%
movie_dt.value_counts('Genre').head(5)
# Out:
# Genre
# Drama                     85
# Drama, Romance            37
# Comedy, Drama             35
# Comedy, Drama, Romance    31
# Action, Crime, Drama      30
# Name: count, dtype: int64

# %%
movie_dt['Gross'] = movie_dt['Gross'].str.replace(',','')
movie_dt
# Out:
#                  Series_Title Released_Year My_Rating  Runtime  \
# 0    The Shawshank Redemption          1994      None  142 min
# 1               The Godfather          1972      None  175 min
# 2             The Dark Knight          2008      None  152 min
# 3      The Godfather: Part II          1974      None  202 min
# 4                12 Angry Men          1957      None   96 min
# ..                        ...           ...       ...      ...
# 995    Breakfast at Tiffany's          1961      None  115 min
# 996                     Giant          1956      None  201 min
# 997     From Here to Eternity          1953      None  118 min
# 998                  Lifeboat          1944      None   97 min
# 999              The 39 Steps          1935      None   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %%
movie_dt.fillna(0, inplace=True)
movie_dt['Gross'] = movie_dt['Gross'].astype('int64')
movie_dt
# Out:
# C:\Users\maniu\AppData\Local\Temp\ipykernel_21868\3163322575.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   movie_dt.fillna(0, inplace=True)
#                  Series_Title Released_Year  My_Rating  Runtime  \
# 0    The Shawshank Redemption          1994          0  142 min
# 1               The Godfather          1972          0  175 min
# 2             The Dark Knight          2008          0  152 min
# 3      The Godfather: Part II          1974          0  202 min
# 4                12 Angry Men          1957          0   96 min
# ..                        ...           ...        ...      ...
# 995    Breakfast at Tiffany's          1961          0  115 min
# 996                     Giant          1956          0  201 min
# ...

# %%
movie_dt.nlargest(n=3, columns=['Gross'])
# Out:
#                                    Series_Title Released_Year  My_Rating  \
# 477  Star Wars: Episode VII - The Force Awakens          2015          0
# 59                            Avengers: Endgame          2019          0
# 623                                      Avatar          2009          0
#
#      Runtime                       Genre  IMDB_Rating  Meta_score  \
# 477  138 min   Action, Adventure, Sci-Fi          7.9        80.0
# 59   181 min    Action, Adventure, Drama          8.4        78.0
# 623  162 min  Action, Adventure, Fantasy          7.8        83.0
#
#           Director            Star1              Star2             Star3  \
# 477    J.J. Abrams     Daisy Ridley        John Boyega       Oscar Isaac
# 59   Anthony Russo        Joe Russo  Robert Downey Jr.       Chris Evans
# 623  James Cameron  Sam Worthington        Zoe Saldana  Sigourney Weaver
#
#                   Star4  No_of_Votes      Gross  Watched
# ...
